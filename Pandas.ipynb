# %% [markdown]
# <a href="https://colab.research.google.com/github/JahnaviMandadi25/PythonForDataEngineering-Beginners2Advanced/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Pandas***

# %% [markdown]
# 1. Reading CSV file using pandas

# %%
import pandas as pd  # Import the pandas library

# Read the CSV file into a DataFrame
df = pd.read_csv('/content/car_price_dataset.csv')

# Print the DataFrame
print(df)
# Out:
# Streaming output truncated to the last 5000 lines.
# 5000     Hyundai   Elantra  2001          1.0    Petrol  Semi-Automatic     4557      4            3   5308
# 5001       Honda    Accord  2021          1.9    Petrol          Manual    29518      2            1  11709
# 5002  Volkswagen      Golf  2016          4.5  Electric       Automatic   179925      5            4  13301
# 5003        Ford    Fiesta  2023          4.8    Hybrid  Semi-Automatic   209679      5            4  12606
# 5004         Kia  Sportage  2022          1.3    Hybrid  Semi-Automatic   239136      2            4   8217
# 5005         BMW  5 Series  2021          3.6    Petrol          Manual   171034      5            1  10579
# 5006  Volkswagen    Tiguan  2001          5.0    Hybrid  Semi-Automatic   255834      3            3   5283
# 5007  Volkswagen    Passat  2000          4.5    Petrol          Manual   179413      3            3   5011
# ...

# %% [markdown]
# 2. Reading JSON files using pandas

# %%
import pandas as pd

df = pd.read_json('/content/banksdata.json')  # Read the JSON file into a DataFrame

print(df.to_string())  # Print the entire DataFrame as a string
# Out:
#     Rank                                Bank Name Total Assets (2023, US$ billion)
# 0      1  Industrial and Commercial Bank of China                         6,303.44
# 1      2               Agricultural Bank of China                         5,623.12
# 2      3                  China Construction Bank                         5,400.28
# 3      4                            Bank of China                         4,578.28
# 4      5                           JPMorgan Chase                         3,875.39
# 5      6                          Bank of America                         3,180.15
# 6      7                                     HSBC                         2,919.84
# 7      8                              BNP Paribas                         2,867.44
# 8      9           Mitsubishi UFJ Financial Group                         2,816.77
# 9     10                          Crédit Agricole                         2,736.95
# ...
